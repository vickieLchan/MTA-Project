# %% [markdown]
# # Benson Challenge

# %%
import sys
print("Python Version:", sys.version)
# Out:
# Python Version: 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# ## Challenge 1

# %%
import pandas as pd

# Do not fill in the number of the csv file name!
first_date_of_csv = "03/30/2019"
# 7 days prior to csv file name.
span_of_days = 42

# def csv_to_df(data_date):
#     csv_file = "turnstile_{}.txt"
#     dfs = []
#     for date in data_date:
#         data_file = csv_file.format(date)
#         dfs.append(pd.read_csv(data_file))
#     return pd.concat(dfs)

# data_date = ["190406", "190413", "190420", "190427", "190504", "190511"]
# df = csv_to_df(data_date)

# %%
def get_data(week_nums):
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt'
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)

week_nums = [190406, 190413, 190420, 190427, 190504, 190511]
df = get_data(week_nums)

# %%
#turnstiles_reg = pd.read_csv(working_directory+'turnstile_data_reg_dt_format.csv', parse_dates=['date', 'date_time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1225024 entries, 0 to 204087
# Data columns (total 11 columns):
# C/A                                                                     1225024 non-null object
# UNIT                                                                    1225024 non-null object
# SCP                                                                     1225024 non-null object
# STATION                                                                 1225024 non-null object
# LINENAME                                                                1225024 non-null object
# DIVISION                                                                1225024 non-null object
# DATE                                                                    1225024 non-null object
# TIME                                                                    1225024 non-null object
# DESC                                                                    1225024 non-null object
# ENTRIES                                                                 1225024 non-null int64
# EXITS                                                                   1225024 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 112.2+ MB

# %%
df = df[df.DESC == "REGULAR"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1219815 entries, 0 to 204087
# Data columns (total 11 columns):
# C/A                                                                     1219815 non-null object
# UNIT                                                                    1219815 non-null object
# SCP                                                                     1219815 non-null object
# STATION                                                                 1219815 non-null object
# LINENAME                                                                1219815 non-null object
# DIVISION                                                                1219815 non-null object
# DATE                                                                    1219815 non-null object
# TIME                                                                    1219815 non-null object
# DESC                                                                    1219815 non-null object
# ENTRIES                                                                 1219815 non-null int64
# EXITS                                                                   1219815 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 111.7+ MB

# %% [markdown]
# ### checking data frame

# %%
df.head()
#df.tail()
#df.info()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6999064
# 1  REGULAR  6999084
# 2  REGULAR  6999107
# 3  REGULAR  6999214
# 4  REGULAR  6999451
#
#    EXITS
# 0                                            2373568
# 1                                            2373576
# 2                                            2373622
# 3                                            2373710
# 4                                            2373781

# %% [markdown]
# ### Clean column names

# %%
def rename_columns():
    column_names = ['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES','EXITS']
    df.columns = [x.lower() for x in column_names]
rename_columns()

# %% [markdown]
# ### checking unique elements

# %%
#df.groupby("time").time.count().sort_values(ascending = False)
#00: and 01: already comprise of 90% of the data! 10% of turnstiles don't submit the first data around midnight!
#df.groupby("date").date.count()
#df.entries.sort_values()

# %% [markdown]
# # Challenge 2

# %%
import dateutil.parser
from datetime import date

def produce_day_hour_column():
    par_funct = lambda row: dateutil.parser.parse(row["date"] + " " + row["time"])
    df["datetime"] = df.apply(par_funct, axis = 1)
    df["day"] = [x.day for x in df.datetime]
    df["hour"] = [x.hour for x in df.datetime]
produce_day_hour_column()

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  16:00:00
#
#       desc  entries    exits            datetime  day  hour
# 0  REGULAR  6999064  2373568 2019-03-30 00:00:00   30     0
# 1  REGULAR  6999084  2373576 2019-03-30 04:00:00   30     4
# 2  REGULAR  6999107  2373622 2019-03-30 08:00:00   30     8
# 3  REGULAR  6999214  2373710 2019-03-30 12:00:00   30    12
# 4  REGULAR  6999451  2373781 2019-03-30 16:00:00   30    16

# %% [markdown]
# # Challenge 3

# %%
turnstile_id = ["c/a", "unit", "scp", "station"]
turnstile_id_date = turnstile_id + ["date"]

# %% [markdown]
# ### checking everything

# %%
#df.groupby(turnstile_id).entries.count()
#df.groupby(turnstile_id_date).entries.count().sort_values()
#entry_and_time_col = ["entries", "date", "hour"]
#df.groupby(turnstile_id_date).hour.min().value_counts()
#dump all the data that starts after 4am (only 1 percent of total data)

# %%
#mask_test = ((df["c/a"] == "PTH18") & (df["unit"] == "R549") & (df["scp"] == "01-01-03") & (df["station"] == "NEWARK BM BW"))

# %%
# are all the cumulative entry counts integers? If function returns nan, cleaning algorithm will be needed
def integer_check():
    for i, value in enumerate(df.entries):
        if type(value) != int:
            print(value)
        elif i == len(df.entries) - 1:
            print("all are int!")
integer_check()
#might need to clean up the entire record of turnstiles that contains nan
df.info()
# Out:
# all are int!
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1219815 entries, 0 to 204087
# Data columns (total 14 columns):
# c/a         1219815 non-null object
# unit        1219815 non-null object
# scp         1219815 non-null object
# station     1219815 non-null object
# linename    1219815 non-null object
# division    1219815 non-null object
# date        1219815 non-null object
# time        1219815 non-null object
# desc        1219815 non-null object
# entries     1219815 non-null int64
# exits       1219815 non-null int64
# datetime    1219815 non-null datetime64[ns]
# day         1219815 non-null int64
# hour        1219815 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(9)
# memory usage: 139.6+ MB

# %% [markdown]
# # Drop duplicate to keep the earilest data each day

# %%
def keep_earliest_hour():
    df1 = df.sort_values('hour', ascending=True).drop_duplicates(turnstile_id_date)
    return df1.sort_values(turnstile_id_date).reset_index(drop=True)
df_keep_earliest_hour = keep_earliest_hour()

# %%
#df_keep_earliest_hour.info()
#df_keep_earliest_hour is the daily cumulative count
#df_keep_earliest_hour.hour.value_counts()
#now drop the rows recorded after 4am
#df_keep_earliest_hour.tail()

# %% [markdown]
# ### drop data after 4am

# %%
#some turnstiles submit the first data of each day at noon, we can't do the daily count based on them.
def keep_midnight():
    return df_keep_earliest_hour[df_keep_earliest_hour.hour < 4].reset_index(drop=True)
df_keep_midnight = keep_midnight()
#df_keep_midnight.hour.value_counts()
df_keep_midnight.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2019  00:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/01/2019  00:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/02/2019  00:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/03/2019  00:00:00
#
#       desc  entries    exits   datetime  day  hour
# 0  REGULAR  6999064  2373568 2019-03-30   30     0
# 1  REGULAR  6999957  2373867 2019-03-31   31     0
# 2  REGULAR  7000528  2374095 2019-04-01    1     0
# 3  REGULAR  7002087  2374579 2019-04-02    2     0
# 4  REGULAR  7003680  2375133 2019-04-03    3     0

# %% [markdown]
# ### checking if turnstiles all have day_span days of data

# %%
 df_keep_midnight.groupby(turnstile_id).entries.count().value_counts()
# 5% of the data has missing day, if wednesday is missing, we might have 
#Wednesday_daily_count = Thursday_cumulative_count - Tuesday_cumulative_count, more cleaning needed!
# Out:
# 42    3567
# 41     818
# 40     182
# 39      96
# 38      63
# 37      39
# 36      30
# 30      12
# 34       8
# 35       8
# 31       6
# 24       6
# 8        5
# 18       5
# 25       3
# 28       3
# 16       3
# 21       1
# 29       1
# 32       1
# 23       1
# 33       1
# Name: entries, dtype: int64

# %% [markdown]
# # Filter rows with less than 42 days of data
# ### filter rows by results of groupby!

# %%
def filter_date_span():
    return df_keep_midnight.groupby(turnstile_id).filter(lambda x: x["entries"].count() > span_of_days -1 ).reset_index(drop=True)
df_filter_date_span = filter_date_span()

# %%
df_filter_date_span.info()
#checking the day span is correct
#df_filter_date_span.groupby(turnstile_id).entries.count().value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149814 entries, 0 to 149813
# Data columns (total 14 columns):
# c/a         149814 non-null object
# unit        149814 non-null object
# scp         149814 non-null object
# station     149814 non-null object
# linename    149814 non-null object
# division    149814 non-null object
# date        149814 non-null object
# time        149814 non-null object
# desc        149814 non-null object
# entries     149814 non-null int64
# exits       149814 non-null int64
# datetime    149814 non-null datetime64[ns]
# day         149814 non-null int64
# hour        149814 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(9)
# memory usage: 16.0+ MB

# %% [markdown]
# # Check the cleaning process again

# %%
# df_filter_date_span.info()
# df_filter_date_span.tail()
# df_filter_date_span.columns
# df_filter_date_span.sample(n = 5, random_state= 41)
# df_filter_date_span.hour.value_counts()
# df_filter_date_span.groupby(turnstile_id).date.count().value_counts()
# df_filter_date_span.entries.max()
#2 billions almost equals to 2 ** 31 , is there a upper limit at which cumulative count got resetted?

# %% [markdown]
# # Daily entries count

# %%
def order_by_date():
    return df_filter_date_span.sort_values(turnstile_id_date).reset_index(drop = True)
df_order_by_date = order_by_date()
#df_order_by_date.count()
# df_order_by_date

# %%
#produce subframe to compute the daily entries, then concatenate to the original dataframe
def diff_daily_count():
    df_sub = df_filter_date_span[["entries"]]
    df_daily_count = df_sub.diff()
    df_daily_count.columns = ["daily_count"]
    return pd.concat([df_order_by_date, df_daily_count], axis=1).reset_index(drop=True)
df_diff_daily_count = diff_daily_count()
#df_diff_daily_count.head()

# %% [markdown]
# ### add previous day

# %%
def add_prev_day():
    df_day = df_diff_daily_count[["date"]]
    df_day_shifted = df_day.shift()
    df_day_shifted.columns = ["prev_date"]
    return pd.concat([df_diff_daily_count, df_day_shifted], axis=1)
df_add_prev_day = add_prev_day()
df_add_prev_day.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/30/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2019  00:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/01/2019  00:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/02/2019  00:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/03/2019  00:00:00
#
#       desc  entries    exits   datetime  day  hour  daily_count   prev_date
# 0  REGULAR  6999064  2373568 2019-03-30   30     0          NaN         NaN
# 1  REGULAR  6999957  2373867 2019-03-31   31     0        893.0  03/30/2019
# 2  REGULAR  7000528  2374095 2019-04-01    1     0        571.0  03/31/2019
# 3  REGULAR  7002087  2374579 2019-04-02    2     0       1559.0  04/01/2019
# 4  REGULAR  7003680  2375133 2019-04-03    3     0       1593.0  04/02/2019

# %% [markdown]
# ### subtraction produces nan, drop the first day!

# %%
def drop_first_day():
    return df_add_prev_day[(df_add_prev_day.date != first_date_of_csv)].reset_index(drop=True)
turnstile_df = drop_first_day()

# %%
turnstile_df.date.nunique()
# Out:
# 41

# %% [markdown]
# # drop positive and negative outliers in daily_entry column

# %%
#all the remaining turnstiles records data during the time span

# %%
#turnstile_df[(turnstile_df.daily_count > 20000)]
#1.8 billion of people went through a turnstile machine in one day?! That's 4 times the US population!

# %%
#by looking at the busiest stations we set the daily count upper bound to 20000
max_daily_cap = 20000
def drop_positive_outlier():
    return turnstile_df.groupby(turnstile_id).filter(lambda x: x['daily_count'].max()< max_daily_cap).reset_index(drop=True)
df_drop_p_outlier = drop_positive_outlier()

# %%
# df_drop_p_outlier[(df_drop_p_outlier.daily_count >max_daily_cap)]
# df_drop_p_outlier[(df_drop_p_outlier.daily_count < 0 )]

# %%
#now drop the neqative data, and the remaining data is sparkling clean!
def cleaned_data():
    return df_drop_p_outlier.groupby(turnstile_id).filter(lambda x: x['daily_count'].min() > 0).reset_index(drop=True)
df_cleaned = cleaned_data()
#df_cleaned[(df_cleaned.daily_count < 0)]

# %%
df_cleaned.desc.value_counts()
# Out:
# REGULAR    97949
# Name: desc, dtype: int64

# %% [markdown]
# # Challenge 4

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from pandas.tseries import converter
import seaborn as sns

# %matplotlib inline

# %%
mask = ((df_cleaned["c/a"] == "A002") & 
(df_cleaned["unit"] == "R051") & 
(df_cleaned["scp"] == "02-00-00") & 
(df_cleaned["station"] == "59 ST"))
# datetime is both name of module and name of constructor of datetime object
df_cleaned
# Out:
#          c/a  unit       scp        station linename division        date  \
# 0       A002  R051  02-00-00          59 ST  NQR456W      BMT  03/31/2019
# 1       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/01/2019
# 2       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/02/2019
# 3       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/03/2019
# 4       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/04/2019
# 5       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/05/2019
# 6       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/06/2019
# 7       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/07/2019
# 8       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/08/2019
# 9       A002  R051  02-00-00          59 ST  NQR456W      BMT  04/09/2019
# 10      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/10/2019
# 11      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/11/2019
# 12      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/12/2019
# 13      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/13/2019
# 14      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/14/2019
# 15      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/15/2019
# 16      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/16/2019
# 17      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/17/2019
# 18      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/18/2019
# 19      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/19/2019
# 20      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/20/2019
# 21      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/21/2019
# 22      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/22/2019
# 23      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/23/2019
# 24      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/24/2019
# 25      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/25/2019
# 26      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/26/2019
# 27      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/27/2019
# 28      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/28/2019
# 29      A002  R051  02-00-00          59 ST  NQR456W      BMT  04/29/2019
# ...      ...   ...       ...            ...      ...      ...         ...
# 97919  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/11/2019
# 97920  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/12/2019
# 97921  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/13/2019
# 97922  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/14/2019
# 97923  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/15/2019
# 97924  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/16/2019
# 97925  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/17/2019
# 97926  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/18/2019
# 97927  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/19/2019
# 97928  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/20/2019
# 97929  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/21/2019
# 97930  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/22/2019
# 97931  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/23/2019
# 97932  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/24/2019
# 97933  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/25/2019
# 97934  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/26/2019
# 97935  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/27/2019
# 97936  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/28/2019
# 97937  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 97938  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 97939  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 97940  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 97941  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 97942  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/04/2019
# 97943  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/05/2019
# 97944  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/06/2019
# 97945  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/07/2019
# 97946  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/08/2019
# 97947  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/09/2019
# 97948  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  05/10/2019
#
#            time     desc  entries    exits            datetime  day  hour  \
# 0      00:00:00  REGULAR  6999957  2373867 2019-03-31 00:00:00   31     0
# 1      00:00:00  REGULAR  7000528  2374095 2019-04-01 00:00:00    1     0
# 2      00:00:00  REGULAR  7002087  2374579 2019-04-02 00:00:00    2     0
# 3      00:00:00  REGULAR  7003680  2375133 2019-04-03 00:00:00    3     0
# 4      00:00:00  REGULAR  7005332  2375557 2019-04-04 00:00:00    4     0
# 5      00:00:00  REGULAR  7006970  2376068 2019-04-05 00:00:00    5     0
# 6      00:00:00  REGULAR  7008540  2376546 2019-04-06 00:00:00    6     0
# 7      00:00:00  REGULAR  7009464  2376791 2019-04-07 00:00:00    7     0
# 8      00:00:00  REGULAR  7010160  2377000 2019-04-08 00:00:00    8     0
# 9      00:00:00  REGULAR  7011693  2377460 2019-04-09 00:00:00    9     0
# 10     00:00:00  REGULAR  7013276  2377962 2019-04-10 00:00:00   10     0
# 11     00:00:00  REGULAR  7014920  2378442 2019-04-11 00:00:00   11     0
# 12     00:00:00  REGULAR  7016533  2378979 2019-04-12 00:00:00   12     0
# 13     00:00:00  REGULAR  7018152  2379496 2019-04-13 00:00:00   13     0
# 14     00:00:00  REGULAR  7019002  2379787 2019-04-14 00:00:00   14     0
# 15     00:00:00  REGULAR  7019671  2379985 2019-04-15 00:00:00   15     0
# 16     00:00:00  REGULAR  7021033  2380362 2019-04-16 00:00:00   16     0
# 17     00:00:00  REGULAR  7022575  2380908 2019-04-17 00:00:00   17     0
# 18     00:00:00  REGULAR  7024115  2381447 2019-04-18 00:00:00   18     0
# 19     00:00:00  REGULAR  7025526  2381946 2019-04-19 00:00:00   19     0
# 20     00:00:00  REGULAR  7026702  2382234 2019-04-20 00:00:00   20     0
# 21     00:00:00  REGULAR  7027457  2382455 2019-04-21 00:00:00   21     0
# 22     00:00:00  REGULAR  7028053  2382642 2019-04-22 00:00:00   22     0
# 23     00:00:00  REGULAR  7029313  2383025 2019-04-23 00:00:00   23     0
# 24     00:00:00  REGULAR  7030821  2383462 2019-04-24 00:00:00   24     0
# 25     00:00:00  REGULAR  7032351  2383896 2019-04-25 00:00:00   25     0
# 26     00:00:00  REGULAR  7033835  2384400 2019-04-26 00:00:00   26     0
# 27     00:00:00  REGULAR  7035249  2384833 2019-04-27 00:00:00   27     0
# 28     00:00:00  REGULAR  7036100  2385087 2019-04-28 00:00:00   28     0
# 29     00:00:00  REGULAR  7036746  2385256 2019-04-29 00:00:00   29     0
# ...         ...      ...      ...      ...                 ...  ...   ...
# 97919  01:00:00  REGULAR  3033112   391257 2019-04-11 01:00:00   11     1
# 97920  01:00:00  REGULAR  3033475   391268 2019-04-12 01:00:00   12     1
# 97921  01:00:00  REGULAR  3033863   391274 2019-04-13 01:00:00   13     1
# 97922  01:00:00  REGULAR  3035467   391333 2019-04-14 01:00:00   14     1
# 97923  01:00:00  REGULAR  3036012   391356 2019-04-15 01:00:00   15     1
# 97924  01:00:00  REGULAR  3036428   391370 2019-04-16 01:00:00   16     1
# 97925  01:00:00  REGULAR  3036932   391388 2019-04-17 01:00:00   17     1
# 97926  01:00:00  REGULAR  3037482   391397 2019-04-18 01:00:00   18     1
# 97927  01:00:00  REGULAR  3037986   391408 2019-04-19 01:00:00   19     1
# 97928  01:00:00  REGULAR  3038529   391413 2019-04-20 01:00:00   20     1
# 97929  01:00:00  REGULAR  3038944   391434 2019-04-21 01:00:00   21     1
# 97930  01:00:00  REGULAR  3039757   391451 2019-04-22 01:00:00   22     1
# 97931  01:00:00  REGULAR  3040061   391460 2019-04-23 01:00:00   23     1
# 97932  01:00:00  REGULAR  3040580   391484 2019-04-24 01:00:00   24     1
# 97933  01:00:00  REGULAR  3041061   391540 2019-04-25 01:00:00   25     1
# 97934  01:00:00  REGULAR  3041568   391564 2019-04-26 01:00:00   26     1
# 97935  01:00:00  REGULAR  3041812   391575 2019-04-27 01:00:00   27     1
# 97936  01:00:00  REGULAR  3042382   391587 2019-04-28 01:00:00   28     1
# 97937  01:00:00  REGULAR  3042731   391602 2019-04-29 01:00:00   29     1
# 97938  01:00:00  REGULAR  3043111   391612 2019-04-30 01:00:00   30     1
# 97939  01:00:00  REGULAR  3043414   391634 2019-05-01 01:00:00    1     1
# 97940  01:00:00  REGULAR  3043667   391642 2019-05-02 01:00:00    2     1
# 97941  01:00:00  REGULAR  3044110   391653 2019-05-03 01:00:00    3     1
# 97942  01:00:00  REGULAR  3044388   391664 2019-05-04 01:00:00    4     1
# 97943  01:00:00  REGULAR  3044778   391676 2019-05-05 01:00:00    5     1
# 97944  01:00:00  REGULAR  3044988   391707 2019-05-06 01:00:00    6     1
# 97945  01:00:00  REGULAR  3045326   391718 2019-05-07 01:00:00    7     1
# 97946  01:00:00  REGULAR  3045673   391730 2019-05-08 01:00:00    8     1
# 97947  01:00:00  REGULAR  3045985   391750 2019-05-09 01:00:00    9     1
# 97948  01:00:00  REGULAR  3046310   391762 2019-05-10 01:00:00   10     1
#
#        daily_count   prev_date
# 0            893.0  03/30/2019
# 1            571.0  03/31/2019
# 2           1559.0  04/01/2019
# 3           1593.0  04/02/2019
# 4           1652.0  04/03/2019
# 5           1638.0  04/04/2019
# 6           1570.0  04/05/2019
# 7            924.0  04/06/2019
# 8            696.0  04/07/2019
# 9           1533.0  04/08/2019
# 10          1583.0  04/09/2019
# 11          1644.0  04/10/2019
# 12          1613.0  04/11/2019
# 13          1619.0  04/12/2019
# 14           850.0  04/13/2019
# 15           669.0  04/14/2019
# 16          1362.0  04/15/2019
# 17          1542.0  04/16/2019
# 18          1540.0  04/17/2019
# 19          1411.0  04/18/2019
# 20          1176.0  04/19/2019
# 21           755.0  04/20/2019
# 22           596.0  04/21/2019
# 23          1260.0  04/22/2019
# 24          1508.0  04/23/2019
# 25          1530.0  04/24/2019
# 26          1484.0  04/25/2019
# 27          1414.0  04/26/2019
# 28           851.0  04/27/2019
# 29           646.0  04/28/2019
# ...            ...         ...
# 97919        403.0  04/10/2019
# 97920        363.0  04/11/2019
# 97921        388.0  04/12/2019
# 97922       1604.0  04/13/2019
# 97923        545.0  04/14/2019
# 97924        416.0  04/15/2019
# 97925        504.0  04/16/2019
# 97926        550.0  04/17/2019
# 97927        504.0  04/18/2019
# 97928        543.0  04/19/2019
# 97929        415.0  04/20/2019
# 97930        813.0  04/21/2019
# 97931        304.0  04/22/2019
# 97932        519.0  04/23/2019
# 97933        481.0  04/24/2019
# 97934        507.0  04/25/2019
# 97935        244.0  04/26/2019
# 97936        570.0  04/27/2019
# 97937        349.0  04/28/2019
# 97938        380.0  04/29/2019
# 97939        303.0  04/30/2019
# 97940        253.0  05/01/2019
# 97941        443.0  05/02/2019
# 97942        278.0  05/03/2019
# 97943        390.0  05/04/2019
# 97944        210.0  05/05/2019
# 97945        338.0  05/06/2019
# 97946        347.0  05/07/2019
# 97947        312.0  05/08/2019
# 97948        325.0  05/09/2019
#
# [97949 rows x 16 columns]

# %%
one_turnstile = df_cleaned[mask]
fig, ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x = 'prev_date',y='daily_count',data= one_turnstile, palette = sns.color_palette("husl", 10));
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set(xlabel='date', ylabel='daily entries', title='Daily Traffic for 59 ST station')
# Out:
# [Text(0, 0.5, 'daily entries'),
#  Text(0.5, 0, 'date'),
#  Text(0.5, 1.0, 'Daily Traffic for 59 ST station')]

# %%
#df_cleaned.info()

# %%
#df_cleaned[((df_cleaned.date ==     "    "  ) & (df_cleaned.daily_count > 5000))][["station", "daily_count"]]

# %% [markdown]
# # Analysis over a single week

# %%
#we choose a condition to consider data in a single week.
one_week_condition = (df_cleaned.day >= 2) & (df_cleaned.day <= 8)

# %%
df_cleaned[one_week_condition & (df_cleaned.station == "GRD CNTRL-42 ST")]\
.groupby(["station", "day"]).daily_count.sum().sort_values()
# Out:
# station          day
# GRD CNTRL-42 ST  8       77393.0
#                  6       78191.0
#                  7       81895.0
#                  5       85125.0
#                  4      124320.0
#                  2      131303.0
#                  3      132719.0
# Name: daily_count, dtype: float64

# %%
df_cleaned[one_week_condition & (df_cleaned.station == "34 ST-PENN STA")]\
.groupby(["station", "day"]).daily_count.sum().sort_values()
# Out:
# station         day
# 34 ST-PENN STA  8      191692.0
#                 6      193170.0
#                 7      199254.0
#                 5      204313.0
#                 4      257401.0
#                 3      259471.0
#                 2      259485.0
# Name: daily_count, dtype: float64

# %%
#different stations
df_cleaned.station.nunique()
# Out:
# 296

# %%
df_cleaned.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/01/2019  00:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/02/2019  00:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/03/2019  00:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/04/2019  00:00:00
#
#       desc  entries    exits   datetime  day  hour  daily_count   prev_date
# 0  REGULAR  6999957  2373867 2019-03-31   31     0        893.0  03/30/2019
# 1  REGULAR  7000528  2374095 2019-04-01    1     0        571.0  03/31/2019
# 2  REGULAR  7002087  2374579 2019-04-02    2     0       1559.0  04/01/2019
# 3  REGULAR  7003680  2375133 2019-04-03    3     0       1593.0  04/02/2019
# 4  REGULAR  7005332  2375557 2019-04-04    4     0       1652.0  04/03/2019

# %%
def map_day_of_week(value):
    if value == 0:
        return 'Sunday'
    elif value == 1:
        return 'Monday'
    elif value == 2:
        return 'Tuesday'
    elif value == 3:
        return 'Wednesday'
    elif value == 4:
        return 'Thursday'
    elif value == 5:
        return 'Friday'
    elif value == 6:
        return 'Saturday'

df_cleaned['weekday'] = df_cleaned.datetime.dt.dayofweek.apply(map_day_of_week)

# %%
df_cleaned.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/01/2019  00:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/02/2019  00:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/03/2019  00:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/04/2019  00:00:00
#
#       desc  entries    exits   datetime  day  hour  daily_count   prev_date  \
# 0  REGULAR  6999957  2373867 2019-03-31   31     0        893.0  03/30/2019
# 1  REGULAR  7000528  2374095 2019-04-01    1     0        571.0  03/31/2019
# 2  REGULAR  7002087  2374579 2019-04-02    2     0       1559.0  04/01/2019
# 3  REGULAR  7003680  2375133 2019-04-03    3     0       1593.0  04/02/2019
# 4  REGULAR  7005332  2375557 2019-04-04    4     0       1652.0  04/03/2019
#
#      weekday
# 0   Saturday
# 1     Sunday
# 2     Monday
# 3    Tuesday
# 4  Wednesday

# %%
df_cleaned['weekday'] = pd.Categorical(df_cleaned['weekday'], categories=
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],
    ordered=True)

# %%
df_cleaned.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/01/2019  00:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/02/2019  00:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/03/2019  00:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/04/2019  00:00:00
#
#       desc  entries    exits   datetime  day  hour  daily_count   prev_date  \
# 0  REGULAR  6999957  2373867 2019-03-31   31     0        893.0  03/30/2019
# 1  REGULAR  7000528  2374095 2019-04-01    1     0        571.0  03/31/2019
# 2  REGULAR  7002087  2374579 2019-04-02    2     0       1559.0  04/01/2019
# 3  REGULAR  7003680  2375133 2019-04-03    3     0       1593.0  04/02/2019
# 4  REGULAR  7005332  2375557 2019-04-04    4     0       1652.0  04/03/2019
#
#      weekday
# 0   Saturday
# 1     Sunday
# 2     Monday
# 3    Tuesday
# 4  Wednesday

# %% [markdown]
# ## station daily entry

# %%
df_station_daily = df_cleaned[one_week_condition].groupby(["station", "weekday", "prev_date"], as_index=False)\
.agg({"daily_count" : "sum"})
df_station_daily[df_station_daily.station == "34 ST-PENN STA"].head(7)
# Out:
#             station    weekday   prev_date  daily_count
# 644  34 ST-PENN STA     Monday  04/01/2019     129764.0
# 645  34 ST-PENN STA     Monday  05/06/2019     124512.0
# 646  34 ST-PENN STA    Tuesday  04/02/2019     129841.0
# 647  34 ST-PENN STA    Tuesday  05/07/2019     126855.0
# 648  34 ST-PENN STA  Wednesday  04/03/2019     131244.0
# 649  34 ST-PENN STA  Wednesday  05/01/2019     129721.0
# 650  34 ST-PENN STA   Thursday  04/04/2019     131297.0

# %%
df_penn = df_station_daily[df_station_daily["station"] == "34 ST-PENN STA"]
ax = sns.barplot(x = 'weekday',y='daily_count',data= df_penn, palette = sns.color_palette("husl", 7));
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set(ylabel='daily entries', title='Penn Station Weekly Traffic')
# Out:
# [Text(0, 0.5, 'daily entries'), Text(0.5, 1.0, 'Penn Station Weekly Traffic')]

# %%
df_station_daily.head(20)
# Out:
#    station    weekday   prev_date  daily_count
# 0     1 AV     Monday  04/01/2019       5677.0
# 1     1 AV     Monday  05/06/2019       5589.0
# 2     1 AV    Tuesday  04/02/2019       7748.0
# 3     1 AV    Tuesday  05/07/2019       5938.0
# 4     1 AV  Wednesday  04/03/2019       8240.0
# 5     1 AV  Wednesday  05/01/2019       5528.0
# 6     1 AV   Thursday  04/04/2019       6136.0
# 7     1 AV   Thursday  05/02/2019       5866.0
# 8     1 AV     Friday  04/05/2019       5469.0
# 9     1 AV     Friday  05/03/2019       6318.0
# 10    1 AV   Saturday  04/06/2019       5676.0
# 11    1 AV   Saturday  05/04/2019       4755.0
# 12    1 AV     Sunday  04/07/2019       4221.0
# 13    1 AV     Sunday  05/05/2019       3488.0
# 14  103 ST     Monday  04/01/2019      17133.0
# 15  103 ST     Monday  05/06/2019      17482.0
# 16  103 ST    Tuesday  04/02/2019      17354.0
# 17  103 ST    Tuesday  05/07/2019      18159.0
# 18  103 ST  Wednesday  04/03/2019      17618.0
# 19  103 ST  Wednesday  05/01/2019      18157.0

# %%
# df_penn = df_station_daily[df_station_daily["station"] == "34 ST-PENN STA"]
top_5 = ['34 ST-PENN STA', 'TIMES SQ-42 ST', '42 ST-PORT AUTH', '86 ST', '34 ST-HERALD SQ']

top_5_df = df_station_daily[df_station_daily.station.isin(top_5)]

plt.figure(figsize= (7,6))
ax = sns.lineplot(x ='weekday',y='daily_count',data= top_5_df, hue='station', palette = sns.color_palette("husl", 5));
plt.xticks(rotation=45)
ax.set(ylabel='daily entries', title='Top 5 Stations - Weekly Traffic')
# Out:
# [Text(0, 0.5, 'daily entries'),
#  Text(0.5, 1.0, 'Top 5 Stations - Weekly Traffic')]

# %% [markdown]
# ## station weekly total

# %%
df_station_weekly =  df_station_daily.groupby(["station"], as_index = False)\
.agg({"daily_count": "sum" }).sort_values(["daily_count"], ascending=False).reset_index(drop=True)

# %%
top_stations = df_station_weekly[df_station_weekly.daily_count > 815000]
ax = sns.barplot(x = 'station',y='daily_count', data = top_stations, palette = sns.color_palette("husl", 7));
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set(ylabel='daily entries', title='Top 5 Stations with Highest Traffic')
# Out:
# [Text(0, 0.5, 'daily entries'),
#  Text(0.5, 1.0, 'Top 5 Stations with Highest Traffic')]

# %% [markdown]
# ## weekly_total MTA count by day of week

# %%
#to compare which day is the busiest day of week:
weekly_total_mta = df_cleaned[one_week_condition].groupby(["weekday"], as_index=False).daily_count.sum()
plt.rcParams["axes.labelsize"] = 12
ax = sns.barplot(x = 'weekday',y='daily_count', data = weekly_total_mta, palette = sns.color_palette("husl", 7));
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set(ylabel='daily entries', title='MTA Weekday Traffic Totals')
# Out:
# [Text(0, 0.5, 'daily entries'), Text(0.5, 1.0, 'MTA Weekday Traffic Totals')]

# %% [markdown]
# ## Daily Entries by Week for One Station

# %%
df_cleaned = df_cleaned.groupby(['station', 'date']).daily_count.agg({'daily_count': 'sum'}).reset_index()
# df_cleaned.head()
penn_station = df_cleaned[df_cleaned['station'] == "34 ST-PENN STA"]
penn_station.head()
# Out:
# /anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#              station        date  daily_count
# 1886  34 ST-PENN STA  03/31/2019      81332.0
# 1887  34 ST-PENN STA  04/01/2019      59851.0
# 1888  34 ST-PENN STA  04/02/2019     129764.0
# 1889  34 ST-PENN STA  04/03/2019     129841.0
# 1890  34 ST-PENN STA  04/04/2019     131244.0

# %%
dates = [dateutil.parser.parse(date) for date in penn_station['date'].values]
counts = penn_station['daily_count'].values

plt.figure(figsize= (10,3))
plt.plot(dates, counts, color='indigo')
plt.title('Total Traffic From 4/06 - 5/11 For Penn Station')
plt.xlabel('Week')
plt.ylabel('Total Entries')
# Out:
# /anaconda3/envs/metis/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Total Entries')

# %% [markdown]
# ## Panel Plot of Time per Weekday

# %%
# g = sns.FacetGrid(tips, col="time", row="smoker")
